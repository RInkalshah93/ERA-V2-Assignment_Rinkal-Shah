# %%
# !nvidia-smi
# Out:
# Fri May 17 23:23:36 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 11.80 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.6 MB/s eta 0:00:00

# %%
# !pip install -r requirements.txt -q
# !pip install Pillow==9.5.0

# %%
#%cd yolov9
# !wget -P weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !unzip box_data.zip
# Out:
# Archive:  box_data.zip
#   inflating: box_data/data.yaml
#    creating: box_data/test/
#    creating: box_data/test/images/
#   inflating: box_data/test/images/01.jpg
#   inflating: box_data/test/images/02.jpg
#   inflating: box_data/test/images/03.jpg
#   inflating: box_data/test/images/04.jpg
#   inflating: box_data/test/images/05.jpg
#   inflating: box_data/test/images/06.jpg
#   inflating: box_data/test/images/07.jpg
#   inflating: box_data/test/images/08.jpg
#   inflating: box_data/test/images/09.jpg
#   inflating: box_data/test/images/10.jpg
#   inflating: box_data/test/images/100.jpg
#  extracting: box_data/test/images/11.jpg
#   inflating: box_data/test/images/12.jpg
#   inflating: box_data/test/images/13.jpg
#   inflating: box_data/test/images/14.jpg
#   inflating: box_data/test/images/15.jpg
#  extracting: box_data/test/images/16.jpg
#   inflating: box_data/test/images/17.jpg
#   inflating: box_data/test/images/18.jpg
#   inflating: box_data/test/images/19.jpg
#   inflating: box_data/test/images/20.jpg
#   inflating: box_data/test/images/21.jpg
#   inflating: box_data/test/images/22.jpg
#   inflating: box_data/test/images/23.jpg
#   inflating: box_data/test/images/24.jpg
#   inflating: box_data/test/images/25.jpg
#   inflating: box_data/test/images/26.jpg
#   inflating: box_data/test/images/27.jpg
#   inflating: box_data/test/images/28.jpg
#   inflating: box_data/test/images/29.jpg
#   inflating: box_data/test/images/30.jpg
#   inflating: box_data/test/images/31.jpg
#   inflating: box_data/test/images/32.jpg
#   inflating: box_data/test/images/33.jpg
#   inflating: box_data/test/images/34.jpg
#   inflating: box_data/test/images/35.jpg
#   inflating: box_data/test/images/36.jpg
#   inflating: box_data/test/images/37.jpg
#   inflating: box_data/test/images/38.jpg
#   inflating: box_data/test/images/39.jpg
#   inflating: box_data/test/images/40.jpg
#   inflating: box_data/test/images/41.jpg
#   inflating: box_data/test/images/42.jpg
#   inflating: box_data/test/images/43.jpg
#   inflating: box_data/test/images/44.jpg
#   inflating: box_data/test/images/45.jpg
#   inflating: box_data/test/images/46.jpg
#   inflating: box_data/test/images/47.jpg
#   inflating: box_data/test/images/48.jpg
#   inflating: box_data/test/images/49.jpg
#   inflating: box_data/test/images/50.jpg
#   inflating: box_data/test/images/51.jpg
#   inflating: box_data/test/images/52.jpg
#   inflating: box_data/test/images/53.jpg
#   inflating: box_data/test/images/54.jpg
#   inflating: box_data/test/images/55.jpg
#   inflating: box_data/test/images/56.jpg
#   inflating: box_data/test/images/57.jpg
#   inflating: box_data/test/images/58.jpg
#   inflating: box_data/test/images/59.jpg
#   inflating: box_data/test/images/60.jpg
#   inflating: box_data/test/images/61.jpg
#   inflating: box_data/test/images/62.jpg
#   inflating: box_data/test/images/63.jpg
#   inflating: box_data/test/images/64.jpg
#   inflating: box_data/test/images/65.jpg
#   inflating: box_data/test/images/66.jpg
#   inflating: box_data/test/images/67.jpg
#   inflating: box_data/test/images/68.jpg
#   inflating: box_data/test/images/69.jpg
#   inflating: box_data/test/images/70.jpg
#   inflating: box_data/test/images/71.jpg
#   inflating: box_data/test/images/72.jpg
#   inflating: box_data/test/images/73.jpg
#   inflating: box_data/test/images/74.jpg
#   inflating: box_data/test/images/75.jpg
#   inflating: box_data/test/images/76.jpg
#   inflating: box_data/test/images/77.jpg
#   inflating: box_data/test/images/78.jpg
#   inflating: box_data/test/images/79.jpg
#   inflating: box_data/test/images/80.jpg
#   inflating: box_data/test/images/81.jpg
#   inflating: box_data/test/images/82.jpg
#   inflating: box_data/test/images/83.jpg
#   inflating: box_data/test/images/84.jpg
#   inflating: box_data/test/images/85.jpg
#   inflating: box_data/test/images/86.jpg
#   inflating: box_data/test/images/87.jpg
#   inflating: box_data/test/images/88.jpg
#   inflating: box_data/test/images/89.jpg
#   inflating: box_data/test/images/90.jpg
#   inflating: box_data/test/images/91.jpg
#   inflating: box_data/test/images/92.jpg
#   inflating: box_data/test/images/93.jpg
#   inflating: box_data/test/images/94.jpg
#   inflating: box_data/test/images/95.jpg
#   inflating: box_data/test/images/96.jpg
#   inflating: box_data/test/images/97.jpg
#   inflating: box_data/test/images/98.jpg
#   inflating: box_data/test/images/99.jpg
#    creating: box_data/test/labels/
#   inflating: box_data/test/labels/01.txt
#   inflating: box_data/test/labels/02.txt
#   inflating: box_data/test/labels/03.txt
#   inflating: box_data/test/labels/04.txt
#   inflating: box_data/test/labels/05.txt
#   inflating: box_data/test/labels/06.txt
#   inflating: box_data/test/labels/07.txt
#   inflating: box_data/test/labels/08.txt
#   inflating: box_data/test/labels/09.txt
#   inflating: box_data/test/labels/10.txt
#   inflating: box_data/test/labels/100.txt
#   inflating: box_data/test/labels/11.txt
#   inflating: box_data/test/labels/12.txt
#   inflating: box_data/test/labels/13.txt
#   inflating: box_data/test/labels/14.txt
#   inflating: box_data/test/labels/15.txt
#   inflating: box_data/test/labels/16.txt
#   inflating: box_data/test/labels/17.txt
#   inflating: box_data/test/labels/18.txt
#   inflating: box_data/test/labels/19.txt
#   inflating: box_data/test/labels/20.txt
#   inflating: box_data/test/labels/21.txt
#   inflating: box_data/test/labels/22.txt
#   inflating: box_data/test/labels/23.txt
#   inflating: box_data/test/labels/24.txt
#   inflating: box_data/test/labels/25.txt
#   inflating: box_data/test/labels/26.txt
#   inflating: box_data/test/labels/27.txt
#   inflating: box_data/test/labels/28.txt
#   inflating: box_data/test/labels/29.txt
#   inflating: box_data/test/labels/30.txt
#   inflating: box_data/test/labels/31.txt
#   inflating: box_data/test/labels/32.txt
#   inflating: box_data/test/labels/33.txt
#   inflating: box_data/test/labels/34.txt
#   inflating: box_data/test/labels/35.txt
#   inflating: box_data/test/labels/36.txt
#   inflating: box_data/test/labels/37.txt
#   inflating: box_data/test/labels/38.txt
#   inflating: box_data/test/labels/39.txt
#   inflating: box_data/test/labels/40.txt
#   inflating: box_data/test/labels/41.txt
#   inflating: box_data/test/labels/42.txt
#   inflating: box_data/test/labels/43.txt
#   inflating: box_data/test/labels/44.txt
#   inflating: box_data/test/labels/45.txt
#   inflating: box_data/test/labels/46.txt
#   inflating: box_data/test/labels/47.txt
#   inflating: box_data/test/labels/48.txt
#   inflating: box_data/test/labels/49.txt
#   inflating: box_data/test/labels/50.txt
#   inflating: box_data/test/labels/51.txt
#   inflating: box_data/test/labels/52.txt
#   inflating: box_data/test/labels/53.txt
#   inflating: box_data/test/labels/54.txt
#   inflating: box_data/test/labels/55.txt
#   inflating: box_data/test/labels/56.txt
#   inflating: box_data/test/labels/57.txt
#   inflating: box_data/test/labels/58.txt
#   inflating: box_data/test/labels/59.txt
#   inflating: box_data/test/labels/60.txt
#   inflating: box_data/test/labels/61.txt
#   inflating: box_data/test/labels/62.txt
#   inflating: box_data/test/labels/63.txt
#   inflating: box_data/test/labels/64.txt
#   inflating: box_data/test/labels/65.txt
#   inflating: box_data/test/labels/66.txt
#   inflating: box_data/test/labels/67.txt
#   inflating: box_data/test/labels/68.txt
#   inflating: box_data/test/labels/69.txt
#   inflating: box_data/test/labels/70.txt
#   inflating: box_data/test/labels/71.txt
#   inflating: box_data/test/labels/72.txt
#   inflating: box_data/test/labels/73.txt
#   inflating: box_data/test/labels/74.txt
#   inflating: box_data/test/labels/75.txt
#   inflating: box_data/test/labels/76.txt
#   inflating: box_data/test/labels/77.txt
#   inflating: box_data/test/labels/78.txt
#   inflating: box_data/test/labels/79.txt
#   inflating: box_data/test/labels/80.txt
#   inflating: box_data/test/labels/81.txt
#   inflating: box_data/test/labels/82.txt
#   inflating: box_data/test/labels/83.txt
#   inflating: box_data/test/labels/84.txt
#   inflating: box_data/test/labels/85.txt
#   inflating: box_data/test/labels/86.txt
#   inflating: box_data/test/labels/87.txt
#   inflating: box_data/test/labels/88.txt
#   inflating: box_data/test/labels/89.txt
#   inflating: box_data/test/labels/90.txt
#   inflating: box_data/test/labels/91.txt
#   inflating: box_data/test/labels/92.txt
#   inflating: box_data/test/labels/93.txt
#   inflating: box_data/test/labels/94.txt
#   inflating: box_data/test/labels/95.txt
#   inflating: box_data/test/labels/96.txt
#   inflating: box_data/test/labels/97.txt
#   inflating: box_data/test/labels/98.txt
#   inflating: box_data/test/labels/99.txt
#    creating: box_data/train/
#    creating: box_data/train/images/
#   inflating: box_data/train/images/01.jpg
#   inflating: box_data/train/images/02.jpg
#   inflating: box_data/train/images/03.jpg
#   inflating: box_data/train/images/04.jpg
#   inflating: box_data/train/images/05.jpg
#   inflating: box_data/train/images/06.jpg
#   inflating: box_data/train/images/84.jpg
#   inflating: box_data/train/images/85.jpg
#   inflating: box_data/train/images/86.jpg
#   inflating: box_data/train/images/87.jpg
#   inflating: box_data/train/images/88.jpg
#   inflating: box_data/train/images/89.jpg
#   inflating: box_data/train/images/90.jpg
#   inflating: box_data/train/images/91.jpg
#   inflating: box_data/train/images/92.jpg
#   inflating: box_data/train/images/93.jpg
#   inflating: box_data/train/images/94.jpg
#   inflating: box_data/train/images/95.jpg
#   inflating: box_data/train/images/96.jpg
#   inflating: box_data/train/images/97.jpg
#   inflating: box_data/train/images/98.jpg
#   inflating: box_data/train/images/99.jpg
#    creating: box_data/train/labels/
#   inflating: box_data/train/labels/01.txt
#   inflating: box_data/train/labels/02.txt
#   inflating: box_data/train/labels/03.txt
#   inflating: box_data/train/labels/04.txt
#   inflating: box_data/train/labels/05.txt
#   inflating: box_data/train/labels/06.txt
#   inflating: box_data/train/labels/07.txt
#   inflating: box_data/train/labels/08.txt
#   inflating: box_data/train/labels/09.txt
#   inflating: box_data/train/labels/10.txt
#   inflating: box_data/train/labels/100.txt
#   inflating: box_data/train/labels/11.txt
#   inflating: box_data/train/labels/12.txt
#   inflating: box_data/train/labels/13.txt
#   inflating: box_data/train/labels/14.txt
#   inflating: box_data/train/labels/15.txt
#   inflating: box_data/train/labels/16.txt
#   inflating: box_data/train/labels/17.txt
#   inflating: box_data/train/labels/18.txt
#   inflating: box_data/train/labels/19.txt
#   inflating: box_data/train/labels/20.txt
#   inflating: box_data/train/labels/21.txt
#   inflating: box_data/train/labels/22.txt
#   inflating: box_data/train/labels/23.txt
#   inflating: box_data/train/labels/24.txt
#   inflating: box_data/train/labels/25.txt
#   inflating: box_data/train/labels/26.txt
#   inflating: box_data/train/labels/27.txt
#   inflating: box_data/train/labels/28.txt
#   inflating: box_data/train/labels/29.txt
#   inflating: box_data/train/labels/30.txt
#   inflating: box_data/train/labels/31.txt
#   inflating: box_data/train/labels/32.txt
#   inflating: box_data/train/labels/33.txt
#   inflating: box_data/train/labels/34.txt
#   inflating: box_data/train/labels/35.txt
#   inflating: box_data/train/labels/36.txt
#   inflating: box_data/train/labels/37.txt
#   inflating: box_data/train/labels/38.txt
#   inflating: box_data/train/labels/39.txt
#   inflating: box_data/train/labels/40.txt
#   inflating: box_data/train/labels/41.txt
#   inflating: box_data/train/labels/42.txt
#   inflating: box_data/train/labels/43.txt
#   inflating: box_data/train/labels/44.txt
#   inflating: box_data/train/labels/45.txt
#   inflating: box_data/train/labels/46.txt
#   inflating: box_data/train/labels/47.txt
#   inflating: box_data/train/labels/48.txt
#   inflating: box_data/train/labels/49.txt
#   inflating: box_data/train/labels/50.txt
#   inflating: box_data/train/labels/51.txt
#   inflating: box_data/train/labels/52.txt
#   inflating: box_data/train/labels/53.txt
#   inflating: box_data/train/labels/54.txt
#   inflating: box_data/train/labels/55.txt
#   inflating: box_data/train/labels/56.txt
#   inflating: box_data/train/labels/57.txt
#   inflating: box_data/train/labels/58.txt
#   inflating: box_data/train/labels/59.txt
#   inflating: box_data/train/labels/60.txt
#   inflating: box_data/train/labels/61.txt
#   inflating: box_data/train/labels/62.txt
#   inflating: box_data/train/labels/63.txt
#   inflating: box_data/train/labels/64.txt
#   inflating: box_data/train/labels/65.txt
#   inflating: box_data/train/labels/66.txt
#   inflating: box_data/train/labels/67.txt
#   inflating: box_data/train/labels/68.txt
#   inflating: box_data/train/labels/69.txt
#   inflating: box_data/train/labels/70.txt
#   inflating: box_data/train/labels/71.txt
#   inflating: box_data/train/labels/72.txt
#   inflating: box_data/train/labels/73.txt
#   inflating: box_data/train/labels/74.txt
#   inflating: box_data/train/labels/75.txt
#   inflating: box_data/train/labels/76.txt
#   inflating: box_data/train/labels/77.txt
#   inflating: box_data/train/labels/78.txt
#   inflating: box_data/train/labels/79.txt
#   inflating: box_data/train/labels/80.txt
#   inflating: box_data/train/labels/81.txt
#   inflating: box_data/train/labels/82.txt
#   inflating: box_data/train/labels/83.txt
#   inflating: box_data/train/labels/84.txt
#   inflating: box_data/train/labels/85.txt
#   inflating: box_data/train/labels/86.txt
#   inflating: box_data/train/labels/87.txt
#   inflating: box_data/train/labels/88.txt
#   inflating: box_data/train/labels/89.txt
#   inflating: box_data/train/labels/90.txt
#   inflating: box_data/train/labels/91.txt
#   inflating: box_data/train/labels/92.txt
#   inflating: box_data/train/labels/93.txt
#   inflating: box_data/train/labels/94.txt
#   inflating: box_data/train/labels/95.txt
#   inflating: box_data/train/labels/96.txt
#   inflating: box_data/train/labels/97.txt
#   inflating: box_data/train/labels/98.txt
#   inflating: box_data/train/labels/99.txt
#    creating: box_data/val/
#    creating: box_data/val/images/
#   inflating: box_data/val/images/01.jpg
#   inflating: box_data/val/images/02.jpg
#   inflating: box_data/val/images/03.jpg
#   inflating: box_data/val/images/04.jpg
#   inflating: box_data/val/images/05.jpg
#   inflating: box_data/val/images/06.jpg
#   inflating: box_data/val/images/07.jpg
#   inflating: box_data/val/images/08.jpg
#   inflating: box_data/val/images/09.jpg
#   inflating: box_data/val/images/10.jpg
#   inflating: box_data/val/images/100.jpg
#  extracting: box_data/val/images/11.jpg
#   inflating: box_data/val/images/12.jpg
#   inflating: box_data/val/images/13.jpg
#   inflating: box_data/val/images/14.jpg
#   inflating: box_data/val/images/15.jpg
#  extracting: box_data/val/images/16.jpg
#   inflating: box_data/val/images/17.jpg
#   inflating: box_data/val/images/18.jpg
#   inflating: box_data/val/images/19.jpg
#   inflating: box_data/val/images/20.jpg
#   inflating: box_data/val/images/21.jpg
#   inflating: box_data/val/images/22.jpg
#   inflating: box_data/val/images/23.jpg
#   inflating: box_data/val/images/24.jpg
#   inflating: box_data/val/images/25.jpg
#   inflating: box_data/val/images/26.jpg
#   inflating: box_data/val/images/27.jpg
#   inflating: box_data/val/images/28.jpg
#   inflating: box_data/val/images/29.jpg
#   inflating: box_data/val/images/30.jpg
#   inflating: box_data/val/images/31.jpg
#   inflating: box_data/val/images/32.jpg
#   inflating: box_data/val/images/33.jpg
#   inflating: box_data/val/images/34.jpg
#   inflating: box_data/val/images/35.jpg
#   inflating: box_data/val/images/36.jpg
#   inflating: box_data/val/labels/91.txt
#   inflating: box_data/val/labels/92.txt
#   inflating: box_data/val/labels/93.txt
#   inflating: box_data/val/labels/94.txt
#   inflating: box_data/val/labels/95.txt
#   inflating: box_data/val/labels/96.txt
#   inflating: box_data/val/labels/97.txt
#   inflating: box_data/val/labels/98.txt
#   inflating: box_data/val/labels/99.txt

# %%
# !python train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data box_data/data.yaml \
--weights weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# 2024-05-17 23:26:54.100874: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 23:26:54.100921: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 23:26:54.102309: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-17 23:26:55.998695: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=box_data/data.yaml, hyp=hyp.scratch-high.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 14.4MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5491411  models.yolo.DDetect                     [1, [256, 512, 512]]
# gelan-c summary: 621 layers, 25437843 parameters, 25437827 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov9/box_data/train/labels... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<00:00, 698.84it/s]
# train: New cache created: /content/yolov9/box_data/train/labels.cache
# val: Scanning /content/yolov9/box_data/val/labels... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<00:00, 867.18it/s]
# val: New cache created: /content/yolov9/box_data/val/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/24      13.4G     0.6899     0.5121      1.126          6        640: 100% 7/7 [00:05<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.01it/s]
#                    all        100        145       0.98       0.89       0.94      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/24      13.4G     0.5993     0.5352      1.025          4        640: 100% 7/7 [00:05<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.04it/s]
#                    all        100        145      0.964       0.89      0.942      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/24      13.4G     0.6397     0.5974      1.114          4        640: 100% 7/7 [00:05<00:00,  1.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.73it/s]
#                    all        100        145      0.975      0.883      0.941      0.799
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/24      13.4G      0.643     0.4473      1.073          6        640: 100% 7/7 [00:05<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.12it/s]
#                    all        100        145       0.94       0.89      0.932      0.792
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/24      13.4G     0.6213     0.4906       1.08          7        640: 100% 7/7 [00:05<00:00,  1.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.91it/s]
#                    all        100        145      0.909        0.9      0.928      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/24      13.4G     0.6663     0.5499      1.056          9        640: 100% 7/7 [00:05<00:00,  1.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.12it/s]
#                    all        100        145      0.914      0.883      0.931      0.789
#
# 25 epochs completed in 0.068 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.00s/it]
#                    all        100        145      0.964      0.883      0.951        0.8
# Results saved to runs/train/exp

# %%
# !ls runs/train/exp/
# Out:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1715988417.e6a95456079d.2145.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
from IPython.display import Image

Image(filename=f"runs/train/exp/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"runs/train/exp/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"runs/train/exp/train_batch0.jpg", width=1000)

# %%
from IPython.display import Image

Image(filename=f"runs/train/exp/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
#%cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data box_data/data.yaml \
--weights runs/train/exp/weights/best.pt
# Out:
# val: data=box_data/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/box_data/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:07<00:00,  1.75s/it]
#                    all        100        145      0.965      0.883      0.951      0.802
# Speed: 0.3ms pre-process, 35.9ms inference, 9.0ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp
